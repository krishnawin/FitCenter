# %%
# !export KERAS_BACKEND="torch"

# %%
import numpy as np
import keras
from keras import layers
import torch
import pandas as pd
import os
import sys
from sklearn.preprocessing import LabelEncoder,StandardScaler
from scipy.spatial.transform import Rotation
module_path = os.path.abspath(os.path.join('../tslearn')) # or the path to your source code
sys.path.insert(0, module_path)
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Create a CNN model with conv1D , batch norm and Relu X 3 layers

# %%
def make_model(input_shape):
    input_layer = keras.layers.Input(input_shape)

    conv1 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(input_layer)
    conv1 = keras.layers.BatchNormalization()(conv1)
    conv1 = keras.layers.ReLU()(conv1)

    conv2 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(conv1)
    conv2 = keras.layers.BatchNormalization()(conv2)
    conv2 = keras.layers.ReLU()(conv2)

    conv3 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(conv2)
    conv3 = keras.layers.BatchNormalization()(conv3)
    conv3 = keras.layers.ReLU()(conv3)

    gap = keras.layers.GlobalAveragePooling1D()(conv3)

    output_layer = keras.layers.Dense(num_classes, activation="softmax")(gap)

    return keras.models.Model(inputs=input_layer, outputs=output_layer)


model = make_model(input_shape=x_train.shape[1:])
keras.utils.plot_model(model, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) for `plot_model` to work.

# %% [markdown]
# ## Define Routines to calculate Quaternion angle

# %%
def quaternion_inverse(q):
  """Calculate the inverse of a quaternion.

  Args:
    q: A quaternion represented as a 4-element numpy array.

  Returns:
    The inverse of the quaternion, represented as a 4-element numpy array.
  """

  q_conj = np.conj(q)
  q_norm = np.linalg.norm(q)
  return q_conj / (q_norm * q_norm)
def quaternion_multiply(q1, q2):
  """Multiply two quaternions.

  Args:
    q1: A quaternion represented as a 4-element numpy array.
    q2: A quaternion represented as a 4-element numpy array.

  Returns:
    The product of the two quaternions, represented as a 4-
    element numpy array.
    
    """
  w1, x1, y1, z1 = q1
  w2, x2, y2, z2 = q2
  w = w1 * w2 - x1 * x2 - y1 * y2 - z1 * z2
  x = w1 * x2 + x1 * w2 + y1 * z2 - z1 * y2
  y = w1 * y2 - x1 * z2 + y1 * w2 + z1 * x2
  z = w1 * z2 + x1 * y2 - y1 * x2 + z1 * w2
  return w, x, y, z
def vec_length(v: np.array):
    return np.sqrt(sum(i**2 for i in v))

def normalize(v):
    norm = np.linalg.norm(v)
    if norm == 0: 
       return v
    return v / norm

def orientation(rs: np.array, ls: np.array):
    axis_z = normalize((rs - ls))
    if vec_length(axis_z) == 0:
        axis_z = np.array((0, -1, 0))
        
    axis_x = np.cross(np.array((0, 0, 1)), axis_z)
    if vec_length(axis_x) == 0:
        axis_x = np.array((1, 0, 0))
    
    axis_y = np.cross(axis_z, axis_x)
    rot_matrix = np.matrix([axis_x, axis_y, axis_z]).transpose()
    #quat=Rotation.from_matrix(rot_matrix).as_quat()
    return Rotation.from_matrix(rot_matrix).as_quat()
def to_quat(df: pd.DataFrame):
    return df.apply(lambda x: orientation(np.array([x[0],x[1],x[2]]),np.array([x[3],x[4],x[5]])),axis=1).to_list()
def get_distance(df:list):
    dfr=[]
    for i in range(0,len(df)-1,2):
        xi = quaternion_inverse(df[i])
        xy = quaternion_multiply(xi,df[i+1])
        dfr.append(2*np.arccos(xy[0])*180/np.pi)
        #dfr.append(np.arccos(xy[0]))
    return dfr

# %% [markdown]
# ## loop thru keypoint files and create Workouts Pandas dataframe and calculate Quaterneon angles

# %%
workouts= pd.DataFrame()
y=[]
for root, dirs, files in os.walk('./Data/MediaPipe/Train'):
        for name in files:
                if(name.endswith('.csv') == False):
                    continue
                filepath = root + os.sep + name
                worktype = filepath.split(os.sep )[-2]
                filename = filepath.split(os.sep)[-1].replace('.csv','')
                if(os.path.getsize(filepath) > 0):
                    df = pd.read_csv(filepath,index_col=0)
                    df1 = pd.DataFrame()
                    #df = df[::round((df.shape[0]/4))]
                    #df_d=calc_euc_dist(df.diff().dropna().pow(2))
                    #df_a=pd.DataFrame()
                    #for i in range(0,33):
                    #    df1 = pd.DataFrame()
                    #    df1['0'] = df.iloc[:,i,]
                    #    df1['1'] = df.iloc[:,i+33]
                    #    df1['2'] = df.iloc[:,i+66]
                    #    df_a= pd.concat([df_a,calculate_euler_angles_from_df(df1)],axis=1,ignore_index=True)
                    #df_x = pd.concat([df_d.reset_index(drop=True),df_a],axis=1,ignore_index=True)
                    """df1[['shoulder_x','shoulder_y','shoulder_z','shoulder_w']] = to_quat(pd.concat([df['11'],df['11.1'],df['11.2'],df['23'],df['23.1'],df['23.2']],axis=1))
                    df1[['hip_x','hip_y','hip_z','hip_w']] = to_quat(pd.concat([df['23'],df['23.1'],df['23.2'],df['24'],df['24.1'],df['24.2']],axis=1))
                    df1[['lhand1_x','lhand1_y','lhand1_z','lhand1_w']] = to_quat(pd.concat([df['11'],df['11.1'],df['11.2'],df['13'],df['13.1'],df['13.2']],axis=1))
                    df1[['rhand1_x','rhand1_y','rhand1_z','rhand1_w']] = to_quat(pd.concat([df['12'],df['12.1'],df['12.2'],df['14'],df['14.1'],df['14.2']],axis=1))
                    df1[['lhand2_x','lhand2_y','lhand2_z','lhand2_w']] = to_quat(pd.concat([df['13'],df['13.1'],df['13.2'],df['15'],df['15.1'],df['15.2']],axis=1))
                    df1[['rhand2_x','rhand2_y','rhand2_z','rhand2_w']] = to_quat(pd.concat([df['14'],df['14.1'],df['14.2'],df['16'],df['16.1'],df['16.2']],axis=1))
                    df1[['lleg1_x','lleg1_y','lleg1_z','lleg1_w']] = to_quat(pd.concat([df['23'],df['23.1'],df['23.2'],df['25'],df['25.1'],df['25.2']],axis=1))
                    df1[['rleg1_x','rleg1_y','rleg1_z','rleg1_w']] = to_quat(pd.concat([df['24'],df['24.1'],df['24.2'],df['26'],df['26.1'],df['26.2']],axis=1))    
                    df1[['lleg2_x','lleg2_y','lleg2_z','lleg2_w']]= to_quat(pd.concat([df['25'],df['25.1'],df['25.2'],df['27'],df['27.1'],df['27.2']],axis=1))
                    df1[['rleg2_x','rleg2_y','rleg2_z','rleg2_w']] = to_quat(pd.concat([df['26'],df['26.1'],df['26.2'],df['28'],df['28.1'],df['28.2']],axis=1))
                    df1[['filename']]= filename
                    """
                    df1['shoulder'] = get_distance(to_quat(pd.concat([df['11'],df['11.1'],df['11.2'],df['23'],df['23.1'],df['23.2']],axis=1)))
                    df1['hip'] = get_distance(to_quat(pd.concat([df['23'],df['23.1'],df['23.2'],df['24'],df['24.1'],df['24.2']],axis=1)))
                    df1['lhand1'] = get_distance(to_quat(pd.concat([df['11'],df['11.1'],df['11.2'],df['13'],df['13.1'],df['13.2']],axis=1)))
                    df1['rhand1'] = get_distance(to_quat(pd.concat([df['12'],df['12.1'],df['12.2'],df['14'],df['14.1'],df['14.2']],axis=1)))
                    df1['lhand2'] = get_distance(to_quat(pd.concat([df['13'],df['13.1'],df['13.2'],df['15'],df['15.1'],df['15.2']],axis=1)))
                    df1['rhand2'] = get_distance(to_quat(pd.concat([df['14'],df['14.1'],df['14.2'],df['16'],df['16.1'],df['16.2']],axis=1)))
                    df1['lleg1'] = get_distance(to_quat(pd.concat([df['23'],df['23.1'],df['23.2'],df['25'],df['25.1'],df['25.2']],axis=1)))
                    df1['rleg1'] = get_distance(to_quat(pd.concat([df['24'],df['24.1'],df['24.2'],df['26'],df['26.1'],df['26.2']],axis=1)))
                    df1['lleg2'] = get_distance(to_quat(pd.concat([df['25'],df['25.1'],df['25.2'],df['27'],df['27.1'],df['27.2']],axis=1)))
                    df1['rleg2'] = get_distance(to_quat(pd.concat([df['26'],df['26.1'],df['26.2'],df['28'],df['28.1'],df['28.2']],axis=1)))
                    #df1['weight'] = df1.diff().fillna(1).pow(2).apply([lambda x: 1 if x >0 else 0 ]).sum(axis=1)/df.shape[1]
                    df1['filename'] = filename
                    
                    #df2=pd.concat([df['11'],df['11.1'],df['11.2'],df['23'],df['23.1'],df['23.2']],axis=1)
                    #df_q = pd.DataFrame(df2.apply(lambda x: orientation(np.array([x[0],x[1],x[2]]),np.array([x[3],x[4],x[5]])),axis=1).to_list(),columns=['q1','q2','q3','q4'])
                    #if(len(df) < 250):
                    #df = pd.concat([df,df_q],axis=1)
                    workouts = pd.concat([workouts,df1],axis=0)
                    y.append(worktype)

# %% [markdown]
# #Scale the data using standard Scaler

# %%
for x in workouts.select_dtypes(include=np.number).columns:
    workouts[x] = StandardScaler().fit_transform(workouts[x].values.reshape(-1,1))

# %%
def reshape(dataset):
    n_ts = len(dataset)
    max_sz = max(
        [ts.shape[0] for ts in dataset]
    )
    d = dataset[0].shape[1]
    dataset_out = np.zeros((n_ts, max_sz, d))
    for i in range(n_ts):
        ts = dataset[i]
        dataset_out[i, : ts.shape[0]] = ts
    return dataset_out

# %% [markdown]
# ## Convert the Dataframe to Timeseries Dataset using reshape method above. This will create numpy array of shape no of Batches, number of time steps, number of bones

# %%
X=workouts.set_index('filename').groupby('filename').apply(pd.DataFrame.to_numpy).to_numpy()
encoder = LabelEncoder()
y = encoder.fit_transform(y)
#formatted_time_series = np.nan_to_num(formatted_time_series,0)
formatted_time_series = reshape(X)
formatted_time_series.shape
X_train, X_test, y_train, y_test = train_test_split(formatted_time_series, y, test_size=0.3, random_state=42, stratify=y)

# %% [markdown]
# # Train The model with loss function as sparse Categorical crossentropy and metrics as sparse_categorical_accuracy . Batch size 32 and 100 epochs

# %%
epochs = 100
batch_size = 32
num_classes = len(np.unique(y_train))
model = make_model(input_shape=X_train.shape[1:])
callbacks = [
    keras.callbacks.ModelCheckpoint(
        "best_model.keras", save_best_only=True, monitor="val_loss"
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001
    ),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["sparse_categorical_accuracy"],
)
history = model.fit(
    X_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.2,
    verbose=1,
)
# Out:
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 347ms/step - loss: 1.6591 - sparse_categorical_accuracy: 0.1521 - val_loss: 1.5454 - val_sparse_categorical_accuracy: 0.5625 - learning_rate: 0.0010
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - loss: 1.3939 - sparse_categorical_accuracy: 0.3049 - val_loss: 1.5011 - val_sparse_categorical_accuracy: 0.6250 - learning_rate: 0.0010
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - loss: 1.2145 - sparse_categorical_accuracy: 0.5437 - val_loss: 1.4569 - val_sparse_categorical_accuracy: 0.6250 - learning_rate: 0.0010
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - loss: 1.0533 - sparse_categorical_accuracy: 0.6618 - val_loss: 1.4188 - val_sparse_categorical_accuracy: 0.6875 - learning_rate: 0.0010
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 0.9872 - sparse_categorical_accuracy: 0.6847 - val_loss: 1.3859 - val_sparse_categorical_accuracy: 0.6875 - learning_rate: 0.0010
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.9251 - sparse_categorical_accuracy: 0.7181 - val_loss: 1.3575 - val_sparse_categorical_accuracy: 0.6875 - learning_rate: 0.0010
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - loss: 0.9054 - sparse_categorical_accuracy: 0.7292 - val_loss: 1.3330 - val_sparse_categorical_accuracy: 0.6875 - learning_rate: 0.0010
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 0.8596 - sparse_categorical_accuracy: 0.7285 - val_loss: 1.3143 - val_sparse_categorical_accuracy: 0.6875 - learning_rate: 0.0010
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.7813 - sparse_categorical_accuracy: 0.7611 - val_loss: 1.2968 - val_sparse_categorical_accuracy: 0.6875 - learning_rate: 0.0010
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.7143 - sparse_categorical_accuracy: 0.8146 - val_loss: 1.2796 - val_sparse_categorical_accuracy: 0.6875 - learning_rate: 0.0010
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.7100 - sparse_categorical_accuracy: 0.8146 - val_loss: 1.2626 - val_sparse_categorical_accuracy: 0.6875 - learning_rate: 0.0010
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.6923 - sparse_categorical_accuracy: 0.8250 - val_loss: 1.2442 - val_sparse_categorical_accuracy: 0.6875 - learning_rate: 0.0010
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 0.6775 - sparse_categorical_accuracy: 0.7944 - val_loss: 1.2288 - val_sparse_categorical_accuracy: 0.6875 - learning_rate: 0.0010
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - loss: 0.6738 - sparse_categorical_accuracy: 0.8368 - val_loss: 1.2123 - val_sparse_categorical_accuracy: 0.6875 - learning_rate: 0.0010
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.5963 - sparse_categorical_accuracy: 0.8472 - val_loss: 1.1987 - val_sparse_categorical_accuracy: 0.6875 - learning_rate: 0.0010
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.5939 - sparse_categorical_accuracy: 0.8146 - val_loss: 1.1830 - val_sparse_categorical_accuracy: 0.6875 - learning_rate: 0.0010
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 0.5806 - sparse_categorical_accuracy: 0.8368 - val_loss: 1.1685 - val_sparse_categorical_accuracy: 0.6250 - learning_rate: 0.0010
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.5696 - sparse_categorical_accuracy: 0.8368 - val_loss: 1.1573 - val_sparse_categorical_accuracy: 0.6250 - learning_rate: 0.0010
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - loss: 0.5162 - sparse_categorical_accuracy: 0.8361 - val_loss: 1.1484 - val_sparse_categorical_accuracy: 0.6875 - learning_rate: 0.0010
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.5307 - sparse_categorical_accuracy: 0.8264 - val_loss: 1.1396 - val_sparse_categorical_accuracy: 0.6875 - learning_rate: 0.0010
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.5165 - sparse_categorical_accuracy: 0.8479 - val_loss: 1.1315 - val_sparse_categorical_accuracy: 0.6875 - learning_rate: 0.0010
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - loss: 0.5179 - sparse_categorical_accuracy: 0.8479 - val_loss: 1.1251 - val_sparse_categorical_accuracy: 0.6875 - learning_rate: 0.0010
# Epoch 23/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.4813 - sparse_categorical_accuracy: 0.8694 - val_loss: 1.1181 - val_sparse_categorical_accuracy: 0.6875 - learning_rate: 0.0010
# Epoch 24/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 0.4490 - sparse_categorical_accuracy: 0.8792 - val_loss: 1.1116 - val_sparse_categorical_accuracy: 0.6875 - learning_rate: 0.0010
# Epoch 25/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 0.4903 - sparse_categorical_accuracy: 0.8806 - val_loss: 1.1071 - val_sparse_categorical_accuracy: 0.6875 - learning_rate: 0.0010
# Epoch 26/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - loss: 0.4509 - sparse_categorical_accuracy: 0.8375 - val_loss: 1.0993 - val_sparse_categorical_accuracy: 0.6875 - learning_rate: 0.0010
# Epoch 27/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 0.4329 - sparse_categorical_accuracy: 0.9236 - val_loss: 1.0924 - val_sparse_categorical_accuracy: 0.6875 - learning_rate: 0.0010
# Epoch 28/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.3914 - sparse_categorical_accuracy: 0.9014 - val_loss: 1.0898 - val_sparse_categorical_accuracy: 0.6875 - learning_rate: 0.0010
# Epoch 29/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.4335 - sparse_categorical_accuracy: 0.8812 - val_loss: 1.0923 - val_sparse_categorical_accuracy: 0.6875 - learning_rate: 0.0010
# Epoch 30/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 0.4154 - sparse_categorical_accuracy: 0.8812 - val_loss: 1.0857 - val_sparse_categorical_accuracy: 0.6875 - learning_rate: 0.0010
# Epoch 31/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.3923 - sparse_categorical_accuracy: 0.9347 - val_loss: 1.0768 - val_sparse_categorical_accuracy: 0.6875 - learning_rate: 0.0010
# Epoch 32/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 0.3861 - sparse_categorical_accuracy: 0.9132 - val_loss: 1.0655 - val_sparse_categorical_accuracy: 0.6875 - learning_rate: 0.0010
# Epoch 33/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 0.3605 - sparse_categorical_accuracy: 0.9340 - val_loss: 1.0526 - val_sparse_categorical_accuracy: 0.6875 - learning_rate: 0.0010
# Epoch 34/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 0.3642 - sparse_categorical_accuracy: 0.9132 - val_loss: 1.0475 - val_sparse_categorical_accuracy: 0.6875 - learning_rate: 0.0010
# Epoch 35/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 0.3336 - sparse_categorical_accuracy: 0.9444 - val_loss: 1.0390 - val_sparse_categorical_accuracy: 0.6875 - learning_rate: 0.0010
# Epoch 36/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.3782 - sparse_categorical_accuracy: 0.9028 - val_loss: 1.0303 - val_sparse_categorical_accuracy: 0.6875 - learning_rate: 0.0010
# Epoch 37/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 0.3321 - sparse_categorical_accuracy: 0.9347 - val_loss: 1.0268 - val_sparse_categorical_accuracy: 0.6875 - learning_rate: 0.0010
# Epoch 38/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 0.3339 - sparse_categorical_accuracy: 0.9243 - val_loss: 1.0211 - val_sparse_categorical_accuracy: 0.6875 - learning_rate: 0.0010
# Epoch 39/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.3080 - sparse_categorical_accuracy: 0.9236 - val_loss: 1.0219 - val_sparse_categorical_accuracy: 0.6875 - learning_rate: 0.0010
# Epoch 40/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.3431 - sparse_categorical_accuracy: 0.9243 - val_loss: 1.0224 - val_sparse_categorical_accuracy: 0.6875 - learning_rate: 0.0010
# Epoch 41/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.3384 - sparse_categorical_accuracy: 0.9347 - val_loss: 1.0271 - val_sparse_categorical_accuracy: 0.6875 - learning_rate: 0.0010
# Epoch 42/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.3082 - sparse_categorical_accuracy: 0.9458 - val_loss: 1.0328 - val_sparse_categorical_accuracy: 0.6875 - learning_rate: 0.0010
# Epoch 43/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.2866 - sparse_categorical_accuracy: 0.9458 - val_loss: 1.0280 - val_sparse_categorical_accuracy: 0.6875 - learning_rate: 0.0010
# Epoch 44/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.2950 - sparse_categorical_accuracy: 0.9667 - val_loss: 1.0158 - val_sparse_categorical_accuracy: 0.6875 - learning_rate: 0.0010
# Epoch 45/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.2444 - sparse_categorical_accuracy: 0.9451 - val_loss: 1.0004 - val_sparse_categorical_accuracy: 0.7500 - learning_rate: 0.0010
# Epoch 46/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - loss: 0.2857 - sparse_categorical_accuracy: 0.9458 - val_loss: 0.9944 - val_sparse_categorical_accuracy: 0.8125 - learning_rate: 0.0010
# Epoch 47/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - loss: 0.2547 - sparse_categorical_accuracy: 0.9563 - val_loss: 0.9906 - val_sparse_categorical_accuracy: 0.8125 - learning_rate: 0.0010
# Epoch 48/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - loss: 0.2570 - sparse_categorical_accuracy: 0.9569 - val_loss: 0.9826 - val_sparse_categorical_accuracy: 0.8125 - learning_rate: 0.0010
# Epoch 49/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.2409 - sparse_categorical_accuracy: 0.9458 - val_loss: 0.9821 - val_sparse_categorical_accuracy: 0.7500 - learning_rate: 0.0010
# Epoch 50/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.2549 - sparse_categorical_accuracy: 0.9354 - val_loss: 0.9786 - val_sparse_categorical_accuracy: 0.7500 - learning_rate: 0.0010
# Epoch 51/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.2260 - sparse_categorical_accuracy: 0.9458 - val_loss: 0.9640 - val_sparse_categorical_accuracy: 0.8125 - learning_rate: 0.0010
# Epoch 52/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 0.2152 - sparse_categorical_accuracy: 0.9563 - val_loss: 0.9478 - val_sparse_categorical_accuracy: 0.8125 - learning_rate: 0.0010
# Epoch 53/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.2177 - sparse_categorical_accuracy: 0.9563 - val_loss: 0.9344 - val_sparse_categorical_accuracy: 0.8125 - learning_rate: 0.0010
# Epoch 54/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 0.2041 - sparse_categorical_accuracy: 0.9674 - val_loss: 0.9304 - val_sparse_categorical_accuracy: 0.8125 - learning_rate: 0.0010
# Epoch 55/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 0.2235 - sparse_categorical_accuracy: 0.9354 - val_loss: 0.9267 - val_sparse_categorical_accuracy: 0.8125 - learning_rate: 0.0010
# Epoch 56/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.2348 - sparse_categorical_accuracy: 0.9458 - val_loss: 0.9375 - val_sparse_categorical_accuracy: 0.8125 - learning_rate: 0.0010
# Epoch 57/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - loss: 0.1775 - sparse_categorical_accuracy: 0.9674 - val_loss: 0.9683 - val_sparse_categorical_accuracy: 0.8125 - learning_rate: 0.0010
# Epoch 58/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.1944 - sparse_categorical_accuracy: 0.9674 - val_loss: 0.9726 - val_sparse_categorical_accuracy: 0.8125 - learning_rate: 0.0010
# Epoch 59/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.1785 - sparse_categorical_accuracy: 0.9563 - val_loss: 0.9468 - val_sparse_categorical_accuracy: 0.8125 - learning_rate: 0.0010
# Epoch 60/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.1607 - sparse_categorical_accuracy: 0.9667 - val_loss: 0.9256 - val_sparse_categorical_accuracy: 0.8125 - learning_rate: 0.0010
# Epoch 61/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.1816 - sparse_categorical_accuracy: 0.9569 - val_loss: 0.9148 - val_sparse_categorical_accuracy: 0.8125 - learning_rate: 0.0010
# Epoch 62/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - loss: 0.1777 - sparse_categorical_accuracy: 0.9458 - val_loss: 0.9081 - val_sparse_categorical_accuracy: 0.8125 - learning_rate: 0.0010
# Epoch 63/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 0.1670 - sparse_categorical_accuracy: 0.9674 - val_loss: 0.8986 - val_sparse_categorical_accuracy: 0.8125 - learning_rate: 0.0010
# Epoch 64/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 0.1634 - sparse_categorical_accuracy: 0.9785 - val_loss: 0.8971 - val_sparse_categorical_accuracy: 0.8125 - learning_rate: 0.0010
# Epoch 65/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 0.1591 - sparse_categorical_accuracy: 0.9785 - val_loss: 0.8948 - val_sparse_categorical_accuracy: 0.8125 - learning_rate: 0.0010
# Epoch 66/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.1556 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.8937 - val_sparse_categorical_accuracy: 0.8125 - learning_rate: 0.0010
# Epoch 67/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 0.1366 - sparse_categorical_accuracy: 0.9889 - val_loss: 0.8905 - val_sparse_categorical_accuracy: 0.8125 - learning_rate: 0.0010
# Epoch 68/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.1478 - sparse_categorical_accuracy: 0.9785 - val_loss: 0.8769 - val_sparse_categorical_accuracy: 0.8125 - learning_rate: 0.0010
# Epoch 69/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.1229 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.8654 - val_sparse_categorical_accuracy: 0.8125 - learning_rate: 0.0010
# Epoch 70/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - loss: 0.1349 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.8499 - val_sparse_categorical_accuracy: 0.8125 - learning_rate: 0.0010
# Epoch 71/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 0.1338 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.8411 - val_sparse_categorical_accuracy: 0.8125 - learning_rate: 0.0010
# Epoch 72/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 0.1330 - sparse_categorical_accuracy: 0.9785 - val_loss: 0.8356 - val_sparse_categorical_accuracy: 0.8125 - learning_rate: 0.0010
# Epoch 73/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 0.1103 - sparse_categorical_accuracy: 0.9889 - val_loss: 0.8332 - val_sparse_categorical_accuracy: 0.8125 - learning_rate: 0.0010
# Epoch 74/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.1191 - sparse_categorical_accuracy: 0.9785 - val_loss: 0.8308 - val_sparse_categorical_accuracy: 0.8125 - learning_rate: 0.0010
# Epoch 75/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.1131 - sparse_categorical_accuracy: 0.9785 - val_loss: 0.8272 - val_sparse_categorical_accuracy: 0.8125 - learning_rate: 0.0010
# Epoch 76/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.1189 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.8274 - val_sparse_categorical_accuracy: 0.8750 - learning_rate: 0.0010
# Epoch 77/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.1295 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.8076 - val_sparse_categorical_accuracy: 0.8750 - learning_rate: 0.0010
# Epoch 78/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - loss: 0.1132 - sparse_categorical_accuracy: 0.9889 - val_loss: 0.7938 - val_sparse_categorical_accuracy: 0.8750 - learning_rate: 0.0010
# Epoch 79/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 0.1180 - sparse_categorical_accuracy: 0.9785 - val_loss: 0.7849 - val_sparse_categorical_accuracy: 0.8750 - learning_rate: 0.0010
# Epoch 80/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - loss: 0.1131 - sparse_categorical_accuracy: 0.9889 - val_loss: 0.7797 - val_sparse_categorical_accuracy: 0.8125 - learning_rate: 0.0010
# Epoch 81/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - loss: 0.0998 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.7739 - val_sparse_categorical_accuracy: 0.8750 - learning_rate: 0.0010
# Epoch 82/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 0.0880 - sparse_categorical_accuracy: 0.9889 - val_loss: 0.7631 - val_sparse_categorical_accuracy: 0.8750 - learning_rate: 0.0010
# Epoch 83/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - loss: 0.0828 - sparse_categorical_accuracy: 0.9889 - val_loss: 0.7573 - val_sparse_categorical_accuracy: 0.8750 - learning_rate: 0.0010
# Epoch 84/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 0.0909 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.7547 - val_sparse_categorical_accuracy: 0.8125 - learning_rate: 0.0010
# Epoch 85/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 0.0852 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.7492 - val_sparse_categorical_accuracy: 0.7500 - learning_rate: 0.0010
# Epoch 86/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - loss: 0.0700 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.7420 - val_sparse_categorical_accuracy: 0.7500 - learning_rate: 0.0010
# Epoch 87/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 0.0824 - sparse_categorical_accuracy: 0.9889 - val_loss: 0.7318 - val_sparse_categorical_accuracy: 0.7500 - learning_rate: 0.0010
# Epoch 88/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 0.0869 - sparse_categorical_accuracy: 0.9785 - val_loss: 0.7180 - val_sparse_categorical_accuracy: 0.7500 - learning_rate: 0.0010
# Epoch 89/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - loss: 0.0781 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.7144 - val_sparse_categorical_accuracy: 0.7500 - learning_rate: 0.0010
# Epoch 90/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 0.0779 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.7116 - val_sparse_categorical_accuracy: 0.8125 - learning_rate: 0.0010
# Epoch 91/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.0986 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.7036 - val_sparse_categorical_accuracy: 0.8125 - learning_rate: 0.0010
# Epoch 92/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0745 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.6913 - val_sparse_categorical_accuracy: 0.8125 - learning_rate: 0.0010
# Epoch 93/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.0710 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.6855 - val_sparse_categorical_accuracy: 0.8125 - learning_rate: 0.0010
# Epoch 94/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.0675 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.6770 - val_sparse_categorical_accuracy: 0.8125 - learning_rate: 0.0010
# Epoch 95/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0694 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.6794 - val_sparse_categorical_accuracy: 0.8125 - learning_rate: 0.0010
# Epoch 96/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0698 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.6796 - val_sparse_categorical_accuracy: 0.8125 - learning_rate: 0.0010
# Epoch 97/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0701 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.6821 - val_sparse_categorical_accuracy: 0.8125 - learning_rate: 0.0010
# Epoch 98/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0676 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.6819 - val_sparse_categorical_accuracy: 0.8125 - learning_rate: 0.0010
# Epoch 99/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0729 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.6780 - val_sparse_categorical_accuracy: 0.8125 - learning_rate: 0.0010
# Epoch 100/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0619 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.6712 - val_sparse_categorical_accuracy: 0.8125 - learning_rate: 0.0010

# %%
model = keras.models.load_model("best_model.keras")

test_loss, test_acc = model.evaluate(X_test, y_test)

print("Test accuracy", test_acc)
print("Test loss", test_loss)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5825 - sparse_categorical_accuracy: 0.9186
# Test accuracy 0.9090909361839294
# Test loss 0.6243724822998047
